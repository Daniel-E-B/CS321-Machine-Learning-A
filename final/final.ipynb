# %%
import pandas as pd
data  = pd.read_csv('appdata.csv')
data.head()
# remove all non english/alphanumeric characters. 
# Replace special characters (eg with accents with normal)
# label binarize genre
# Out:
#                                                title  \
# 0                                     Wax it Loyalty
# 1                                       Circles Mail
# 2                                              isiee
# 3  Combat Trigger: Modern Gun & Top FPS Shooting ...
# 4                      TuneIn Radio Pro - Live Radio
#
#                                          description  \
# 0  Download Wax it App today It’s an easy way to ...
# 1  Circles by PiXiL is the most elegant email cli...
# 2  Jetzt bekommen Sie alle Infos, Termine und Kon...
# 3  Extreme features:\r\n- exciting campaign with ...
# 4  Listen to your favorite radio stations for fre...
#
#                                              summary     score  price  \
# 0                   Wax it Loyalty app for Customers  3.285714   0.00
# 1  Circles offers the full feature mail clinet fo...  3.317365   0.00
# 2                       The app for Grasmück dealer.  3.666667   0.00
# 3  FIGHT AGAINST ALIENS IN MODERN BATTLES AND SHO...  3.899250   0.00
# 4       Listen to music, news, sports &amp; podcasts  4.246939   9.99
#
#                              developer             genre             genreId  \
# 0                               WAX IT  Health & Fitness  HEALTH_AND_FITNESS
# 1          PiXiL International Company      Productivity        PRODUCTIVITY
# 2  Grasmück Insektenschutzsysteme GmbH          Business            BUSINESS
# 3            ThunderBull Entertainment            Action         GAME_ACTION
# 4                           TuneIn Inc     Music & Audio     MUSIC_AND_AUDIO
#
#    minInstalls
# 0         5000
# 1        10000
# 2          100
# 3      1000000
# 4      1000000

# %%
# drop genreId
data = data.drop("genreId", 1)
data.head()
# Out:
#                                                title  \
# 0                                     Wax it Loyalty
# 1                                       Circles Mail
# 2                                              isiee
# 3  Combat Trigger: Modern Gun & Top FPS Shooting ...
# 4                      TuneIn Radio Pro - Live Radio
#
#                                          description  \
# 0  Download Wax it App today It’s an easy way to ...
# 1  Circles by PiXiL is the most elegant email cli...
# 2  Jetzt bekommen Sie alle Infos, Termine und Kon...
# 3  Extreme features:\r\n- exciting campaign with ...
# 4  Listen to your favorite radio stations for fre...
#
#                                              summary     score  price  \
# 0                   Wax it Loyalty app for Customers  3.285714   0.00
# 1  Circles offers the full feature mail clinet fo...  3.317365   0.00
# 2                       The app for Grasmück dealer.  3.666667   0.00
# 3  FIGHT AGAINST ALIENS IN MODERN BATTLES AND SHO...  3.899250   0.00
# 4       Listen to music, news, sports &amp; podcasts  4.246939   9.99
#
#                              developer             genre  minInstalls
# 0                               WAX IT  Health & Fitness         5000
# 1          PiXiL International Company      Productivity        10000
# 2  Grasmück Insektenschutzsysteme GmbH          Business          100
# 3            ThunderBull Entertainment            Action      1000000
# 4                           TuneIn Inc     Music & Audio      1000000

# %%
# lowercasing, scaling from 0 to 1, verify ascii all in one go :)
to_lower = ["title", "description", "summary", "developer", "genre"]
min, max = 0, 5
scale0to1 = ["score"]
verify_ascii = ["title", "description", "summary", "developer", "genre"]
replace_dict = { '＆' : '&', 'ü' : 'u', 'ー' : '-', 'í' : 'i', 'ó' : 'o', 'é' : 'e', '“' : '"', '–' : '-',
                'о' : 'o', 'а' : 'a', 'ä' : 'a', 'å' : 'a', 'ö' : 'o', 'ű' : 'u', 'ú' : 'u', 'á' : 'a', 'ί' : 'i',
                'ο' : 'o', 'ç' : 'c', 'õ' : 'o', 'ã' : 'a', '”' : '"', '…' : '...', 'à' : 'a', 'у' : 'y', 'х' : 'x',
                'ğ' : 'g', 'ọ' : 'o', '（' : '(', '）' : ')', '１' : '1', '！' : '!', 'ş': 's', '～' : '~', '—' : '-',
                'ị' : 'i', 'ý' : 'y', 'ạ' : 'a', 'ê' : 'e', 'ñ' : 'n', 'ό' : 'o', 'š' : 's', 'č' : 'c', 'đ' : 'd',
                'ừ' : 'u', 'ể' : 'e', 'ữ' : 'u', 'ơ' : 'o', 'ń' : 'n', 'إ' : '!', 'ậ' : 'a', 'ả' : 'a', 'ộ' : 'o',
                'く' : '<', 'ї' : 'i', 'ù' : 'u', 'ā' : 'a', 'ṇ' : 'n', 'ệ' : 'e', 'ư' : 'u', 'ờ' : 'o', 'ř' : 'r',
                'أ' : 'i', 'ë' : 'e', 'ắ' : 'a', 'ô' : 'o', 'ố' : 'o', 'ž' : 'z', '＜' : '<', '２' : '2', '＞' : '>',
                '４' : '4', '：' : ':', '３' : '3', 'ề' : 'e', 'ì' : 'i', 'ổ' : 'o', 'è' : 'e', 'ａ' : 'a', 'ｒ' : 'r',
                '８' : '8', '６' : '6', 'ś' : 's', 'ớ' : 'o', 'ẻ' : 'e', '５' : '5', '０' : '0', 'ż' : 'z', 'ź' : 'z',
                'ę' : 'e', 'ă' : 'a', '－' : '-', '？' : '?', 'ứ' : 'u', 'ế' : 'e', 'ň' : 'n', '，' : ',', 'ů' : 'u',
                'ě' : 'e', '㎡' : 'm', '‐' : '-', '｜' : '|', 'ợ' : 'o', 'ấ' : 'a', 'ự' : 'u', '／' : '/', '○' : 'o',
                '×' : 'x', '［' : '[', '］' : ']', 'ẹ' : 'e', '〜' : '~', 'ｄ' : 'd', 'ｗ' : 'w', 'ņ' : 'n', 'ｌ' : '|',
                'ｉ' : 'i', 'ｎ' : 'n', 'ｅ' : 'e', '＋' : '+', 'ė' : 'e', '¡' : 'i', 'ģ' : 'g', 'ć' : 'c', 'ഠ' : 'o',
                'ｋ' : 'k', 'ј' : 'j', 'ｐ' : 'p', 'ｇ' : 'g', 'ｆ' : 'f', 'ｏ' : 'o', 'ș' : 's', 'ˈ' : "'", '‘' : "'",
                'ų' : 'u', 'į' : 'i', 'ū' : 'u', 'ą' : 'a', 'ё' : 'e', 'ѓ' : 'r', '％' : '%', 'î' : 'i', 'ļ' : 'l',
                'ē' : 'e', 'ï' : 'i', '＊' : '*', 'ụ' : 'u', 'ễ' : 'e', 'ẫ' : 'a', 'ỗ' : 'o', 'ở' : 'o', 'ẳ' : 'a',
                'ồ' : 'o', 'ỹ' : 'y', 'ỉ' : 'i', 'ỳ' : 'y', 'ｃ' : 'c', '９' : '9', 'ｓ' : 's', 'ũ' : 'u', 'ặ' : 'a',
                'ầ' : 'a', 'û' : 'u', '״' : '"', ', ': ',', 'ţ' : 't', 'ỏ' : 'o', 'ẽ' : 'e', '⁃' : '-', 'ｘ' : 'x',
                'ỷ' : 'y', 'ť' : 't', 'ΐ' : 'i', '―' : '-',  'ϊ' : 'i', '＝' : '=', 'ˆ' : '^', 'ṣ' : 's', '─' : '-',
                'ｖ' : 'v', 'ｑ' : 'q', 'ⅰ' : 'i', 'ℹ' : 'i', 'ț' : 't', 'ｂ' : 'b', 'ħ' : 'h', 'ġ' : 'g', 'ċ' : 'c',
                'ľ' : 'l', 'ď' : 'd', '＄' : '$', 'ɑ' : 'a', '＼' : '\\', 'ऽ' : 's', '‹' : '<', 'ｈ' : 'h', '＂' : '"',
                'ട' : 's', 'ḷ' : 'l', 'ㅣ' : '|', 'ㅡ' : '-', '✼' : '*', 'ẵ' : 'a', '✚' : '+', '․' : '.', '═' : '=',
                '❝' : '"', '❞' : '"', '⁺' : '+', 'ဝ' : 'c', 'ǐ' : 'i', 'ǔ' : 'u', '❛' : 'a', '⋆' : '*', 'ｍ' : 'm',
                'ｰ' : '-', '✻' : '*', 'ƒ' : 'f', '＾' : '^', '∗' : '*', '−' : '-', '❇' : '*', '＿' : '_', '丨' : '|',
                'ｙ' : 'y', 'ｚ' : 'z', 'ẓ' : 'z' }
# irregulars = []
for col in data:
    if col in to_lower:
        data[col] = data[col].str.lower()
    if col in scale0to1:
        data[col] = data[col] / (max - min)
    if col in verify_ascii:
# PLEASE DO NOT RUN THIS... it takes forever, and is used to generate a list of characters that I might want to replace        
#         try:
#             for word in data[col]:
#                 for char in word:
#                     try:
#                         char.encode('ascii')
#                     except:
#                         if char not in irregulars:
#                             irregulars.append(char)
#         except:
#             print(data[col])
# irregulars

# if one contains more than a certain % of non ascii characters, remove it
data.head()
# Out:
#   File "<ipython-input-25-cbe75b71d77a>", line 20
#     'ｋ' : 'k', 'ј' : 'j', 'ｐ' : 'p', 'ｇ' : 'g', 'ｆ' : 'f', 'ｏ' : 'o', 'ș' : 's', 'ˈ' : "'", '‘' : ,'ų', 'į', 'ū', 'ą', 'ё', 'ѓ', '☀',  '％',  'î',  'ļ', 'ē',  'ï', '＊',  'ụ', 'ễ', 'ẫ', 'ỗ', 'ở', 'ẳ', 'ồ', 'ỹ', 'ỉ', 'ỳ',  'ｃ', '９', 'ｓ',  'ũ', 'ặ', 'ầ',  'û',  '״', '׳', 'ţ',  'ỏ', 'ẽ','⁃',  'ｘ',  'ỷ',  'ť', 'ΐ', '―',  'ϊ', '＝',  'ˆ', 'ṣ', '─','ｖ', 'ｑ',  'ⅰ','ℹ', 'ț', 'ｂ',  'ħ', 'ġ', 'ċ',  'ľ', 'ď', '＄',  'ɑ', '＼', 'ऽ',  '‹', 'ｈ', '＂',  'ട',  'ḷ', 'ㅣ', 'ㅡ', '✼',  'ẵ',  '✚',  '․', '═', '❝', '❞', '⁺', 'ဝ',  'ǐ', 'ǔ',  'ː',  '❛', '⋆',  'ｍ',  'ｰ', '✻',  'ƒ', '＾', '∗', '−',  '❇', '＿', '丨', 'ｙ', 'ｚ', 'ẓ', 'ٰ''
#                                                                                                   ^
# SyntaxError: invalid syntax

# %%
# Out:
# jj

# %%
print(irregulars)
# Out:
# ['健', '康', '手', '帖', 'お', '薬', '帳', '＆', '病', '院', '検', '索', 'ü', 'イ', 'ケ', 'メ', 'ン', '王', '宮', '◆', '真', '夜', '中', 'の', 'シ', 'デ', 'レ', 'ラ', '恋', '愛', 'ゲ', 'ー', 'ム', 'í', 'ð', 'ó', 'é', '“', '™', '–', 'п', 'о', 'в', 'ы', 'ш', 'а', 'й', '영', '어', '기', '적', '의', '일', '북', '패', '턴', 'ä', 'å', 'ö', '중', '학', '본', '단', '맛', '보', 'ű', 'ú', 'á', '이', '동', '원', '로', '목', '사', '설', '교', '전', '용', '行', '銷', '教', '父', '나', '첫', '토', '익', '新', '版', '湯', '水', '保', '養', '生', '離', '線', '香', '港', '製', '造', 'л', 'и', 'г', 'т', 'н', 'с', 'к', 'я', 'з', 'ا', 'ل', 'ق', 'ر', 'آ', 'ن', 'ك', 'ي', 'م', 'ه', 'ع', '강', '남', '대', '®', '北', '市', '警', '政', '행', '정', '법', '총', '론', '판', '례', '듣', '프', '리', '미', '엄', 'א', 'ר', 'ץ', 'ע', 'י', 'ג', 'ם', 'ח', 'ב', '暮', '鐘', '偈', '唱', '誦', '🏖', '️', 'δ', 'ί', 'π', 'λ', 'ω', 'μ', 'α', 'ο', 'τ', 'σ', 'υ', 'κ', 'έ', 'ς', 'ı', 'ค', 'ณ', 'ิ', 'ต', 'ฯ', 'ด', 'เ', 'ร', '็', 'ว', '예', '비', 'ぺ', 'そ', 'ぎ', 'ん', '占', 'い', '無', '料', '輕', '鬆', '猜', '數', '字', '德', '州', '撲', '克', '至', '尊', 'ж', 'е', 'д', 'р', 'ь', 'ص', 'ح', 'ج', 'غ', 'و', 'ز', 'د', 'ت', '유', '치', '틀', '파', '닉', '스', '모', '키', '즈', '무', '인', '형', '도', '돌', '런', '처', '폰', '트', 'ç', 'õ', 'ã', '랜', '덤', '채', '팅', '네', '잎', '클', '버', '찾', '”', 'ι', 'ν', 'ή', 'さ', 'す', 'う', 'ろ', 'ど', '子', '供', 'た', 'め', '足', 'し', '算', '引', 'き', '学', '習', 'ア', 'プ', 'リ', 'η', '…', 'ρ', 'γ', 'χ', 'ε', '소', '송', '심', '오', '디', '조', '문', 'à', '防', '範', '各', '種', '異', '端', '試', '閱', 'у', 'х', 'ğ', '̇', '카', '톡', '글', '꼴', '쉐', '킷', 'ọ', '日', '独', '英', 'か', '国', '語', '会', '話', '辞', '典', '\u3000', '（', '三', '省', '堂', '）', 'ط', 'ب', 'خ', '가', '엘', '성', '경', '개', '역', 'ю', 'м', 'б', 'س', 'ض', '계', '술', '서', '관', '호', '갱', '님', '우', '고', '요', '금', '산', '뽐', '뿌', '료', '플', '巨', '虫', '図', '鑑', 'ト', 'ำ', 'ม', 'โ', 'น', 'ๆ', 'ก', 'แ', 'ง', '다', '번', '찬', 'モ', 'コ', '赤', '外', '안', '드', '림', '아', '·', '여', '장', '애', '찰', '지', '센', '터', '目', '標', '管', '理', '１', 'ヶ', '月', 'を', '立', 'て', 'よ', '！', 'ş', '시', '즌', '픈', '크', '릿', '쥬', 'ス', 'マ', 'ハ', 'こ', 'や', 'ロ', 'タ', '～', '秘', '密', 'ピ', '몰', '테', '해', '외', '직', '구', '작', '배', 'β', 'э', '診', '療', '放', '射', '技', '師', '家', '験', '過', '去', '問', '—', '汉', '词', 'ő', 'ị', 'ý', 'ạ', 'ê', 'ц', '음', '력', '양', '변', '환', '위', '期', '間', '限', '定', 'ポ', '自', '動', 'チ', 'ェ', 'ッ', 'ク', '楽', '天', '場', 'پ', 'ش', 'ک', 'ñ', 'θ', 'ό', 'ξ', 'ф', 'š', 'č', 'đ', 'ừ', 'ể', 'ữ', 'ơ', '快', '碼', '건', '삼', '국', '책', '략', 'ń', 'ł', '為', '替', 'フ', 'ל', 'ו', 'מ', 'â', '체', '마', '뱅', '킹', 'ט', 'ד', 'ש', 'ヒ', 'バ', 'ド', '払', '心', '仕', '事', '、', '求', '人', '情', '報', 'サ', '聞', '小', '時', '直', '播', '열', '린', '들', '세', '旧', '羽', '化', 'щ', 'إ', 'ة', 'ậ', 'ả', 'ộ', '잡', '신', '入', '力', '補', '助', 'ら', 'く', '数', 'あ', '→', '等', '証', '明', '写', 'ツ', 'ル', '【', '分', 'で', 'る', '】', 'カ', 'グ', '選', '名', '書', '年', '素', '材', 'も', 'が', 'キ', 'ャ', 'อ', '์', 'ี', '้', 'า', 'ї', 'ù', 'パ', '回', '転', '電', '卓', 'ה', 'כ', 'ث', '鏡', '第', '二', '大', '修', '館', '店', '旅', '游', '语', '看', '畫', '學', '會', '計', '베', '블', '랙', '박', '젼', 'ホ', 'テ', 'ч', '알', '高', '校', '受', '単', '톨', '릭', '독', '락', '通', '信', '監', '視', '暇', 'つ', 'ぶ', '瘋', '麻', '將', '張', '空', '室', 'ā', 'ṇ', 'ī', '발', '文', '單', '背', '的', '最', '佳', '利', '器', '민', '칙', 'ử', 'ệ', 'ư', 'ờ', 'ř', 'ά', '題', 'な', '本', '증', '권', '통', 'ズ', '安', '値', 'っ', 'と', '便', 'に', 'ま', 'ת', 'נ', 'ך', 'ק', 'ィ', '活', '皇', '甜', '品', '國', '泰', '綜', '合', '醫', 'ニ', 'ュ', '・', '気', '地', '震', '災', '좋', '은', '습', '만', '표', '달', '東', '京', '한', '자', '공', '부', '엔', '러', '觸', '摸', '偵', '探', '菇', '栽', '培', '研', '究', '四', '季', '티', '빙', '실', '간', '방', '화', '급', '머', 'セ', 'ァ', 'ョ', '販', '粧', '買', '物', '携', '程', '徒', '疑', '难', '问', '与', '答', '简', '爽', '밀', '푸', '딩', '華', '瀚', '經', '홈', '앤', '쇼', '핑', '앱', '에', '할', '립', '븐', '럭', '하', '노', '및', '출', '결', '勉', '強', '原', '루', '링', 'ガ', '와', '쳐', '올', '편', '富', '豪', 'だ', 'ふ', 'ご', '法', '則', '朝', '倉', 'أ', '바', '↔', 'ë', '汚', '染', '予', '黄', '砂', '선', '상', '험', '画', '⇒', '像', '存', '’', 'え', '漬', 'け', '멤', '십', 'ف', 'ء', '和', '鍼', '灸', '式', '関', '節', '可', '域', '仮', ...
